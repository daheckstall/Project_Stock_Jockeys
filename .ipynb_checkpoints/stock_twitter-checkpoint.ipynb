# %%
# %matplotlib inline

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import seaborn as sns
import time
import tweepy
from datetime import datetime
 
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from tw_config import (consumer_key,
                       consumer_secret,
                       access_token,
                       access_token_secret)

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Load S&P500 Company List
df_sp500 = pd.read_csv('Resources/SP500_Company_List.csv')
df_sp500 = df_sp500[0:50]
df_sp500.head()
# Out:
#   Ticker             Security             GICS Sector  \
# 0    MMM           3M Company             Industrials
# 1    ABT  Abbott Laboratories             Health Care
# 2   ABBV          AbbVie Inc.             Health Care
# 3   ABMD          ABIOMED Inc             Health Care
# 4    ACN        Accenture plc  Information Technology
#
#                 GICS Sub Industry                 Location  Date Added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota         NaN
# 1           Health Care Equipment  North Chicago, Illinois   3/31/1964
# 2                 Pharmaceuticals  North Chicago, Illinois  12/31/2012
# 3           Health Care Equipment   Danvers, Massachusetts   5/31/2018
# 4  IT Consulting & Other Services          Dublin, Ireland    7/6/2011
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3   815094
# 4  1467373

# %%
# Find Twitter handles for S&P500 Companies - RUN IF SP500_twtr_handles.csv DOES NOT ALREADY EXIST. 
twtr_handles = []

# Search for Twitter handles by Company Name
for index, row in df_sp500.iterrows(): 
    try:
        user_id = ''
        screen_name = ''
        name = ''
        
        time.sleep(1)                                                  # Keep API Calls under limit
        public_users = api.search_users(row.Security)
        re_name = re.search('[\w]+', row.Security)
        loc = re.search('[\w]+$', row.Location)
        if len(public_users) > 0:
            for user in public_users:
                if (re_name.group(0).lower() in user['name'].lower()):
                    user_id = user['id']
                    screen_name = user['screen_name']
                    name = user['name']
                    break
                
                elif (row.Security.lower() in user['name'].lower()):
                    user_id = user['id']
                    screen_name = user['screen_name']
                    name = user['name']
                
        twtr_handles.append([row.Ticker, row.Security, loc.group(0).lower(), user_id, screen_name, name])
        #print(f'Company Match: [{row.Ticker},{row.Security},{loc.group(0).lower()},{user_id},{screen_name},{name}]')
        
    except Exception as e:
        print(e)

# Search for Twitter handles with different company name search
for i in range(len(twtr_handles)):
    try:
        if twtr_handles[i][3] == '':                                     # Check if user_id is blank
            time.sleep(1)                                                # Keep API Calls under limit
            re_name = re.search('[\w]+ [\w]+', twtr_handles[i][1])
            if re_name != None:
                public_users = api.search_users(re_name.group(0).lower())
            
                if len(public_users) > 0:
                    for user in public_users:
                        if (re_name.group(0).lower() in user['name'].lower()):
                            user_id = user['id']
                            screen_name = user['screen_name']
                            name = user['name']
                            twtr_handles[i] = [twtr_handles[i][0],twtr_handles[i][1],twtr_handles[i][2],user_id,screen_name,name]
                            #print(f'2nd Company Search: {twtr_handles[i]}')
                            break
                           
                        elif (twtr_handles[i][1].lower() in user['name'].lower()):
                            user_id = user['id']
                            screen_name = user['screen_name']
                            name = user['name']
                            twtr_handles[i] = [twtr_handles[i][0],twtr_handles[i][1],twtr_handles[i][2],user_id,screen_name,name]
                            #print(f'2nd Company Search: {twtr_handles[i]}')
                            
    except Exception as e:
        print(e)        
        
# Search for Twitter handles by ticker symbol
for i in range(len(twtr_handles)):
    try:
        if twtr_handles[i][3] == '':                                     # Check if user_id is blank
            time.sleep(1)                                                # Keep API Calls under limit
            public_users = api.search_users(f'${twtr_handles[i][0]}')
            
            if len(public_users) > 0:
                for user in public_users:
                    if re.search('[\w]+', twtr_handles[i][1]).group(0).lower() in user['name'].lower():
                        user_id = user['id']
                        screen_name = user['screen_name']
                        name = user['name']
                        twtr_handles[i] = [twtr_handles[i][0],twtr_handles[i][1],twtr_handles[i][2],user_id,screen_name,name]
                        #print(f'Ticker Match: {twtr_handles[i]}')
                        break
                        
                    elif re.search('[\w]+ [\w]+', twtr_handles[i][1]).group(0).lower() in user['name'].lower():
                        user_id = user['id']
                        screen_name = user['screen_name']
                        name = user['name']
                        twtr_handles[i] = [twtr_handles[i][0],twtr_handles[i][1],twtr_handles[i][2],user_id,screen_name,name]
                        #print(f'Ticker Match: {twtr_handles[i]}')
                        break
                        
                    elif (twtr_handles[i][0] == user['name']) and (user['followers_count'] > 10000):
                        user_id = user['id']
                        screen_name = user['screen_name']
                        name = user['name']
                        twtr_handles[i] = [twtr_handles[i][0],twtr_handles[i][1],twtr_handles[i][2],user_id,screen_name,name]
                        #print(f'Ticker Match: {twtr_handles[i]}')
                      
    except Exception as e:
        print(e)

df_twtr_handles = pd.DataFrame(twtr_handles, columns=['ticker','security','location','user_id','screen_name','twtr_name'])
df_twtr_handles = df_twtr_handles.drop(columns=['location'])
df_twtr_handles.to_csv('Resources/SP500_twtr_handles.csv', index=False)
# Out:
# Company Match: [MMM,3M Company,minnesota,378197959,3M,3M]
# Company Match: [ABT,Abbott Laboratories,illinois,1934702336,AbbottGlobal,Abbott]
# Company Match: [ABBV,AbbVie Inc.,illinois,531892451,abbvie,AbbVie]
# Company Match: [ABMD,ABIOMED Inc,massachusetts,,,]
# Company Match: [ACN,Accenture plc,ireland,,,]
# Company Match: [ATVI,Activision Blizzard,california,753670706311815169,ATVI_AB,Activision Blizzard]
# Company Match: [ADBE,Adobe Systems Inc,california,,,]
# Company Match: [AMD,Advanced Micro Devices Inc,california,,,]
# Company Match: [AAP,Advance Auto Parts,virginia,76762658,AdvanceAuto,Advance Auto Parts]
# Company Match: [AES,AES Corp,virginia,2541746143,TheAESCorp,The AES Corporation]
# Company Match: [AET,Aetna Inc,connecticut,16188518,Aetna,Aetna]
# Company Match: [AMG,Affiliated Managers Group Inc,massachusetts,,,]
# Company Match: [AFL,AFLAC Inc,georgia,551154824,pf_afl,Aflac Inc]
# Company Match: [A,Agilent Technologies Inc,california,,,]
# Company Match: [APD,Air Products & Chemicals Inc,pennsylvania,109634966,airproducts,Air Products]
# Company Match: [AKAM,Akamai Technologies Inc,massachusetts,19622847,Akamai,Akamai Technologies]
# Company Match: [ALK,Alaska Air Group Inc,washington,,,]
# Company Match: [ALB,Albemarle Corp,louisiana,342316270,AlbemarleCorp,Albemarle Corp.]
# Company Match: [ARE,Alexandria Real Estate Equities Inc,california,,,]
# Company Match: [ALXN,Alexion Pharmaceuticals,connecticut,,,]
# Company Match: [ALGN,Align Technology,california,988456283287121920,AlignTechInc,Align Technology]
# Company Match: [ALLE,Allegion,ireland,480738493,AllegionUS,Allegion US]
# Company Match: [AGN,Allergan, Plc,ireland,164787325,Allergan,Allergan plc]
# Company Match: [ADS,Alliance Data Systems,texas,133000328,E3Alliance,E3 Alliance]
# Company Match: [LNT,Alliant Energy Corp,wisconsin,556874482,lnt4f8ec4477ea,Alliant Energy Corp]
# Company Match: [ALL,Allstate Corp,illinois,3599926396,AllstateCan,Allstate Can Corp]
# Company Match: [GOOGL,Alphabet Inc Class A,california,,,]
# Company Match: [GOOG,Alphabet Inc Class C,california,,,]
# Company Match: [MO,Altria Group Inc,virginia,556921726,mo4f8ed270614aa,Altria Group Inc]
# Company Match: [AMZN,Amazon.com Inc.,washington,20793816,amazon,Amazon.com]
# Company Match: [AEE,Ameren Corp,missouri,55526996,AmerenCorp,Ameren Corporation]
# Company Match: [AAL,American Airlines Group,texas,,,]
# Company Match: [AEP,American Electric Power,ohio,,,]
# Company Match: [AXP,American Express Co,york,42712551,AmericanExpress,American Express]
# Company Match: [AIG,American International Group, Inc.,york,,,]
# Company Match: [AMT,American Tower Corp A,massachusetts,,,]
# Company Match: [AWK,American Water Works Company Inc,jersey,,,]
# Company Match: [AMP,Ameriprise Financial,minnesota,164011937,ameriprise,Ameriprise Financial]
# Company Match: [ABC,AmerisourceBergen Corp,pennsylvania,,,]
# Company Match: [AME,AMETEK Inc.,pennsylvania,256996215,AMETEKInc,AMETEK Inc.]
# Company Match: [AMGN,Amgen Inc.,california,28436760,Amgen,Amgen]
# Company Match: [APH,Amphenol Corp,connecticut,1179932060,AmphenolACC,Amphenol CAN MilAero]
# Company Match: [APC,Anadarko Petroleum Corp,texas,,,]
# Company Match: [ADI,Analog Devices, Inc.,massachusetts,37722624,ADI_News,Analog Devices, Inc.]
# Company Match: [ANDV,Andeavor,texas,1566547009,andeavor,Andeavor]
# Company Match: [ANSS,ANSYS,pennsylvania,33647963,ANSYS,ANSYS]
# Company Match: [ANTM,Anthem Inc.,indiana,435302260,AnthemInc,Anthem, Inc.]
# Company Match: [AON,Aon plc,kingdom,22152077,Aon_plc,Aon]
# Company Match: [AOS,A.O. Smith Corp,wisconsin,,,]
# Company Match: [APA,Apache Corporation,texas,57098362,ApacheCorp,Apache Corporation]
# 2nd Company Search: ['AMD', 'Advanced Micro Devices Inc', 'california', 124658229, 'ConnectRemote', 'Advanced Micro Tech']
# 2nd Company Search: ['A', 'Agilent Technologies Inc', 'california', 17278322, 'Agilent', 'Agilent Technologies']
# 2nd Company Search: ['ALK', 'Alaska Air Group Inc', 'washington', 13192972, 'AlaskaAir', 'Alaska Airlines']
# 2nd Company Search: ['GOOGL', 'Alphabet Inc Class A', 'california', 25995637, 'alec_petty', 'alphabet inc']
# 2nd Company Search: ['GOOG', 'Alphabet Inc Class C', 'california', 25995637, 'alec_petty', 'alphabet inc']
# 2nd Company Search: ['AAL', 'American Airlines Group', 'texas', 22536055, 'AmericanAir', 'American Airlines']
# 2nd Company Search: ['AEP', 'American Electric Power', 'ohio', 132213917, 'BayAreaElectric', 'American Electrical']
# 2nd Company Search: ['AMT', 'American Tower Corp A', 'massachusetts', 2998877622, 'the_englishouse', 'American Tower']
# 2nd Company Search: ['AWK', 'American Water Works Company Inc', 'jersey', 25565709, 'amwater', 'American Water']
# 2nd Company Search: ['APC', 'Anadarko Petroleum Corp', 'texas', 859461997016088576, 'AnadarkoPetrol', 'Anadarko Petroleum']
# Ticker Match: ['ACN', 'Accenture plc', 'ireland', 10194682, 'Accenture', 'Accenture']
# Ticker Match: ['ADBE', 'Adobe Systems Inc', 'california', 63786611, 'Adobe', 'Adobe']
# Ticker Match: ['AMG', 'Affiliated Managers Group Inc', 'massachusetts', 2206920425, 'amgmusic_', 'AMG']
# Ticker Match: ['AIG', 'American International Group, Inc.', 'york', 126118683, 'AIGinsurance', 'AIG']
# Ticker Match: ['AOS', 'A.O. Smith\xa0Corp', 'wisconsin', 523687787, 'ArtOfShades', 'AOS']

# %%
public_users = api.search_users('$AIG')
public_users[0]
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Wed Mar 24 22:10:39 +0000 2010',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': "Global insurance company serving clients in 80+ countries. We’re committed to preparing our clients for what's next. For service, tweet us! 👋",
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'aig.com',
#      'expanded_url': 'http://www.aig.com',
#      'indices': [0, 22],
#      'url': 'http://t.co/1Q1cbaVvyn'}]}},
#  'favourites_count': 456,
#  'follow_request_sent': False,
#  'followers_count': 37357,
#  'following': False,
#  'friends_count': 251,
#  'geo_enabled': False,
#  'has_extended_profile': False,
#  'id': 126118683,
#  'id_str': '126118683',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 567,
#  'location': 'Worldwide',
#  'name': 'AIG',
#  'notifications': False,
#  'profile_background_color': 'EDF3F5',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/126118683/1476796087',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/523226011949740032/FaYE8a8k_normal.png',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/523226011949740032/FaYE8a8k_normal.png',
#  'profile_link_color': '00A4E4',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'E6F6F9',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'AIGinsurance',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Jun 28 20:23:39 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 56897877,
#      'id_str': '56897877',
#      'indices': [0, 15],
#      'name': 'Em Brown',
#      'screen_name': 'EmBrownisfunny'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1012431353646809088,
#   'id_str': '1012431353646809088',
#   'in_reply_to_screen_name': 'EmBrownisfunny',
#   'in_reply_to_status_id': 1012420930742767617,
#   'in_reply_to_status_id_str': '1012420930742767617',
#   'in_reply_to_user_id': 56897877,
#   'in_reply_to_user_id_str': '56897877',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'text': '@EmBrownisfunny Hi Em, please email us at CSU@aig.com so we can look into your claim further.',
#   'truncated': False},
#  'statuses_count': 4453,
#  'time_zone': None,
#  'translator_type': 'regular',
#  'url': 'http://t.co/1Q1cbaVvyn',
#  'utc_offset': None,
#  'verified': True}

# %%
re_name = re.search('[\w]+ [\w]+', 'American')
print(re_name)

# %%
nl = int(np.around(len('test')*.66))
regex = '[\D\d]{%s}' %(nl)
regex
