# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df_sp500_data = pd.read_csv('Resources/SP500_filing_data.csv')

df_sp500_data['netcash_free'] = df_sp500_data.netcash_operating - df_sp500_data.ppe_purchases
df_sp500_data['prev_netcash_free'] = df_sp500_data.prev_netcash_operating - df_sp500_data.prev_ppe_purchases
len(df_sp500_data)
# Out:
# 41238

# %%
# Out:
#   company_code    cik filing_type  filing_period  netincomeloss  \
# 0          MMM  66740        10-K       20141231     4956000000
# 1          MMM  66740        10-K       20141231     4956000000
# 2          MMM  66740        10-K       20141231     4956000000
# 3          MMM  66740        10-K       20141231     4956000000
# 4          MMM  66740        10-K       20141231     4956000000
#
#    prev_netincomeloss  retainedearnings  prev_retainedearnings  \
# 0        4.659000e+09       34317000000            32416000000
# 1        4.659000e+09       34317000000            32416000000
# 2        4.659000e+09       34317000000            32416000000
# 3        4.659000e+09       34317000000            32416000000
# 4        4.659000e+09       34317000000            32416000000
#
#    netcash_operating  prev_netcash_operating  netcash_investing  \
# 0         5300000000              5817000000        -2686000000
# 1         5300000000              5817000000        -2686000000
# ...
